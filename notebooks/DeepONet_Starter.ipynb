# %%
import os 
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('..')
import deepxde as dde
from deepxde.backend import pytorch as bkd

from utils.data_utils import read_hdf
from dataloaders.simple_dataloader import SimpleDataset, get_cr_dirs
from dataloaders.deeponet_dataloader import DeepONetDataset
from utils.gif_generator import create_gif_from_array

# %%
DATA_DIR = '/data/solar_wind_pred_predsci/hdf'

# %%
cr_dirs = get_cr_dirs(DATA_DIR)
split_ix = int(len(cr_dirs) * 0.4)
cr_train, cr_val = cr_dirs[:split_ix], cr_dirs[split_ix:]
train_dataset = SimpleDataset(DATA_DIR, cr_train, scale_up=1, pos_embedding=False)
# Out:
# Loading simulations: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 224/224 [00:01<00:00, 137.28it/s]

# %%
grid_pts = train_dataset.get_grid_points()

# %%
grid_pts[0]
# Out:
# array([ 30.      ,  31.485323,  32.970646,  34.45597 ,  35.941296,
#         37.42662 ,  38.91194 ,  40.397266,  41.88259 ,  43.367912,
#         44.853237,  46.338562,  47.823883,  49.309208,  50.794533,
#         52.279858,  53.76518 ,  55.250504,  56.73583 ,  58.22115 ,
#         59.706474,  61.1918  ,  62.677124,  64.162445,  65.647766,
#         67.133095,  68.618416,  70.103745,  71.589066,  73.07439 ,
#         74.559715,  76.04504 ,  77.53036 ,  79.015686,  80.50101 ,
#         81.98633 ,  83.47166 ,  84.95698 ,  86.4423  ,  87.92763 ,
#         89.41295 ,  90.89827 ,  92.3836  ,  93.86892 ,  95.35425 ,
#         96.83957 ,  98.32489 ,  99.81022 , 101.29554 , 102.78086 ,
#        104.26619 , 105.75151 , 107.23683 , 108.72216 , 110.20748 ,
#        111.6928  , 113.17813 , 114.66345 , 116.14877 , 117.6341  ,
#        119.11942 , 120.60475 , 122.09007 , 123.57539 , 125.06072 ,
#        126.54604 , 128.03137 , 129.5167  , 131.00201 , 132.48734 ,
# ...

# %%
deeponet_dataset = DeepONetDataset(DATA_DIR, cr_train, scale_up=1, pos_embedding=False)
# Out:
# Loading simulations: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 224/224 [00:01<00:00, 145.62it/s]

# %%
sample = deeponet_dataset[0]
print(sample["branch"].shape, sample["trunk"].shape, sample["target"].shape)
# Out:
# torch.Size([14208]) torch.Size([1974912, 3]) torch.Size([1974912])

# %%
train_dataset[0]['x'].shape
# Out:
# torch.Size([1, 111, 128])
